# %% [markdown]
# ## descriptive statistics

# %%
import numpy as np 
x = np.array([10,20,30,40,50,60,70,80,90])
print(x)
y = np.max(x)
print(y)
z =np.min(x)
print(z)
a = np.median(x)
print(a)
# Out:
# [10 20 30 40 50 60 70 80 90]
# 90
# 10
# 50.0
