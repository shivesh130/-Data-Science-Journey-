# %% [markdown]
# ## struture array
# * it allow you to store different in single numpy any simlier table on a database

# %%
import numpy as np
a =np.array([(101,"xyz",80.9),(102,"abc",64.3)],
            dtype=[("rollno","i4"),("name","U10"),("mark","f4")])
print(a["name"][1])
print(a["rollno"][0])
# Out:
# abc
# 101
