# %%
Datatypes of numpy

# %%
import numpy as np

# %%
d = np.array(["shiv"],dtype='U2')
print(d.dtype)
c =np.array(["shievsh","anjali"], dtype='U5')
print(c)
# Out:
# <U2
# ['shiev' 'anjal']

# %%
c = np.array([129],dtype=np.int8)
print(c)  #error due out of range -128 to +127
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 c = np.array([129],dtype=np.int8)
#       2 print(c)
#
# OverflowError: Python integer 129 out of bounds for int8

# %%
c = np.array([129],dtype=np.float16)
print(c)
print(c.dtype)
# Out:
# [129.]
# float16
