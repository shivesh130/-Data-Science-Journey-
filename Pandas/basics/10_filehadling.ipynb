# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\shive\OneDrive\Desktop\Data-science-journey\Pandas\basics\ecommerce_data_200_rows_.csv")
print(df.head(10))
# Out:
#    OrderID Customer     Product     Category  Price       City
# 0     1001     Liam       Mouse  Electronics    700    Chennai
# 1     1002  Charlie       Shoes      Fashion   2500      Delhi
# 2     1003     Jack    Backpack      Fashion   2200     Jaipur
# 3     1004      Bob      Laptop  Electronics  55000       Pune
# 4     1005     Jack       Shoes      Fashion   2500    Kolkata
# 5     1006     Liam    Backpack      Fashion   2200  Bengaluru
# 6     1007    Henry  Headphones  Electronics   1800    Chennai
# 7     1008     Liam      Laptop  Electronics  55000     Jaipur
# 8     1009  Charlie        Book        Books    450       Pune
# 9     1010      Bob        Book        Books    450     Jaipur

# %%
df.to_csv("cleaned_data.csv",index=False)
df.head(10)
# Out:
#    OrderID Customer     Product     Category  Price       City
# 0     1001     Liam       Mouse  Electronics    700    Chennai
# 1     1002  Charlie       Shoes      Fashion   2500      Delhi
# 2     1003     Jack    Backpack      Fashion   2200     Jaipur
# 3     1004      Bob      Laptop  Electronics  55000       Pune
# 4     1005     Jack       Shoes      Fashion   2500    Kolkata
# 5     1006     Liam    Backpack      Fashion   2200  Bengaluru
# 6     1007    Henry  Headphones  Electronics   1800    Chennai
# 7     1008     Liam      Laptop  Electronics  55000     Jaipur
# 8     1009  Charlie        Book        Books    450       Pune
# 9     1010      Bob        Book        Books    450     Jaipur
