# %% [markdown]
# ## data insecption and exploration

# %% [markdown]
# # viewing
# * -head() defualt show top 5 rows
# * -tail()   default show ;ast 5rows
# * -sample()  show randomly rows all to input

# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\shive\OneDrive\Pictures\whatsapp\employees_details.csv")
print(df)
# Out:
#    EmployeeID            Name   Department  Salary JoiningDate
# 0        E001        John Doe           HR   50000  2020-01-15
# 1        E002      jane smith           IT   65000  2019-03-22
# 2        E003     Bob Johnson        SALES   55000         NaN
# 3        E004     alice brown           IT   65000  2021-02-10
# 4        E005             NaN  Engineering   70000  2018-05-30
# 5        E006   Charlie Davis           hr   52000  2022-01-01
# 6        E007  diana martinez        Sales   58000  2020-11-20
# 7        E008     evan wilson          NaN   60000  2019-07-14
# 8        E009    Fiona Garcia  Engineering   75000  2021-04-05
# 9        E010   george thomas           IT   65000  2020-06-18
# 10       E011  Hannah Jackson    MARKETING   48000         NaN
# 11       E012        Ivan Lee  Engineering   72000  2019-09-12
# 12       E013  julia anderson           hr   51000  2022-03-08
# 13       E014     Kevin White           IT   67000  2020-12-25
# ...

# %%
print(df.head())
# Out:
#   EmployeeID         Name   Department  Salary JoiningDate
# 0       E001     John Doe           HR   50000  2020-01-15
# 1       E002   jane smith           IT   65000  2019-03-22
# 2       E003  Bob Johnson        SALES   55000         NaN
# 3       E004  alice brown           IT   65000  2021-02-10
# 4       E005          NaN  Engineering   70000  2018-05-30

# %%
print(df.tail())
# Out:
#    EmployeeID           Name   Department  Salary JoiningDate
# 25       E026      Uma Patel           IT   66000  2021-03-25
# 26       E027  victor santos           HR   52000  2019-12-01
# 27       E028    wendy brown  Engineering   72500         NaN
# 28       E029            NaN        SALES   54000  2020-08-17
# 29       E030    zoe johnson           it   63000  2021-06-06

# %%
print(df.sample(3))
# Out:
#    EmployeeID           Name   Department  Salary JoiningDate
# 22       E023  robert martin  Engineering   74000  2018-04-12
# 17       E018   Nancy Taylor    MARKETING   49000  2020-02-28
# 15       E016      Lisa Chen  Engineering   73000  2018-08-22

# %% [markdown]
# # Data information
# - info()    show the information of data like row ,column ,dtype, etc.
# - describe()   show the total calculation of count,mean,std,min,max
# - describe(include="object")    shows the total count, unqiue,top,frequency

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   30 non-null     object
#  1   Name         26 non-null     object
#  2   Department   28 non-null     object
#  3   Salary       30 non-null     int64
#  4   JoiningDate  26 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB
# None

# %%
print(df.describe())
# Out:
#              Salary
# count     30.000000
# mean   61116.666667
# std     8685.782411
# min    48000.000000
# 25%    52500.000000
# 50%    62500.000000
# 75%    67750.000000
# max    75000.000000

# %%
print(df.describe(include="object"))
# Out:
#        EmployeeID      Name Department JoiningDate
# count          30        26         28          26
# unique         30        26         10          26
# top          E001  John Doe         IT  2020-01-15
# freq            1         1          7           1

# %% [markdown]
# # unqiue value
# - unique() :- retuen unique values in data
# - nunquie()  :- return count of unique values in every column

# %%
print(df['Salary'].unique())
# Out:
# [50000 65000 55000 70000 52000 58000 60000 75000 48000 72000 51000 67000
#  73000 64000 49000 71000 56000 68000 74000 62000 66000 72500 54000 63000]

# %%
print(df['Salary'].nunique())
# Out:
# 24

# %% [markdown]
# # value count

# %%
print(df['Department'].value_counts())
# Out:
# Department
# IT             7
# Engineering    7
# HR             3
# SALES          2
# hr             2
# Sales          2
# MARKETING      2
# sales          1
# Marketing      1
# it             1
# Name: count, dtype: int64

# %%
print(df['Salary'].value_counts(normalize=True))
# Out:
# Salary
# 65000    0.100000
# 50000    0.066667
# 55000    0.066667
# 52000    0.066667
# 51000    0.066667
# 49000    0.033333
# 54000    0.033333
# 72500    0.033333
# 66000    0.033333
# 62000    0.033333
# 74000    0.033333
# 68000    0.033333
# 56000    0.033333
# 71000    0.033333
# 73000    0.033333
# 64000    0.033333
# 67000    0.033333
# 72000    0.033333
# 48000    0.033333
# 75000    0.033333
# 60000    0.033333
# 58000    0.033333
# 70000    0.033333
# 63000    0.033333
# Name: proportion, dtype: float64
