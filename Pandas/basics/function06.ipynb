# %% [markdown]
# - concat
# - merge
# - join
# - handling key and index

# %% [markdown]
# ## concat
# - it is used combine  dataframe vertically or horizontally

# %%
import pandas as pd
dic = { "mark":[88,76,92,44,59]
       }
dic1= {"age":[20,21,22,24,19]}
df1 = pd.DataFrame(dic)
df2 = pd.DataFrame(dic1)
rsult2 = pd.concat([df1,df2])
print(rsult2)
rsult1 = pd.concat([df1,df2],ignore_index=True)
print(rsult1)
rsult3 = pd.concat([df1,df2],ignore_index=True ,axis =1)
print(rsult3)
rsult4 = pd.concat([df1,df2],ignore_index=True ,axis =0)
print(rsult4)
# Out:
#    mark   age
# 0  88.0   NaN
# 1  76.0   NaN
# 2  92.0   NaN
# 3  44.0   NaN
# 4  59.0   NaN
# 0   NaN  20.0
# 1   NaN  21.0
# 2   NaN  22.0
# 3   NaN  24.0
# 4   NaN  19.0
#    mark   age
# 0  88.0   NaN
# 1  76.0   NaN
# 2  92.0   NaN
# 3  44.0   NaN
# 4  59.0   NaN
# 5   NaN  20.0
# 6   NaN  21.0
# 7   NaN  22.0
# 8   NaN  24.0
# 9   NaN  19.0
#     0   1
# 0  88  20
# 1  76  21
# 2  92  22
# 3  44  24
# 4  59  19
#    mark   age
# 0  88.0   NaN
# 1  76.0   NaN
# 2  92.0   NaN
# 3  44.0   NaN
# 4  59.0   NaN
# 5   NaN  20.0
# 6   NaN  21.0
# 7   NaN  22.0
# 8   NaN  24.0
# 9   NaN  19.0

# %% [markdown]
# ## merge()
# - it combine the dataframe using a common column
# - it work like the join in sql

# %%
dic = { "mark":[88,76,92,44,59]
       }
dic1= {"mark":[20,21,22,24,19]}
df1 = pd.DataFrame(dic)
df2 = pd.DataFrame(dic1)
pd.merge(df1,df2)
pd.merge(df1,df2,on="mark")
# Out:
# Empty DataFrame
# Columns: [mark]
# Index: []

# %% [markdown]
# ## inner merge()
# -
