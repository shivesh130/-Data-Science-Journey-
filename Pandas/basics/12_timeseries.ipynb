# %% [markdown]
# # Time series Anlaysis
# - Data and time data type
# - converting data time
# - Time indexing
# -
# - Polling and expanding windows

# %% [markdown]
# ### Data and time dtype

# %%
import pandas as pd 
df = pd.DataFrame({
    'Emply':['A','B','C','D'],
    'join_date':['2023-09-04','2044-08-02','2034-05-03','2008-04-11']
})

print(df)
print(df.dtypes)
print("-----------converting to datatime-----------------")
df['join_date'] = pd.to_datetime(df['join_date'])
print(df.dtypes)
# Out:
#   Emply   join_date
# 0     A  2023-09-04
# 1     B  2044-08-02
# 2     C  2034-05-03
# 3     D  2008-04-11
# Emply        str
# join_date    str
# dtype: object
# -----------converting to datatime-----------------
# Emply                   str
# join_date    datetime64[us]
# dtype: object

# %%
# we can access the year, month,day separatly after converting 
print("----------------represent in year-----------------")
df['year'] = df['join_date'].dt.year
#print(df)
print("--------------represent in month----------------")
df['month'] = df['join_date'].dt.month
#print(df)
print("--------------represent in day----------------")
df['week'] = df['join_date'].dt.day_name()
df['week'] = df['join_date'].dt.day

print(df)
# Out:
# ----------------represent in year-----------------
# --------------represent in month----------------
# --------------represent in day----------------
#   Emply  join_date  year  month  week  \
# 0     A 2023-09-04  2023      9     4
# 1     B 2044-08-02  2044      8     2
# 2     C 2034-05-03  2034      5     3
# 3     D 2008-04-11  2008      4    11
#
#                                                  day
# 0  <bound method DatetimeArray.day_name of <panda...
# 1  <bound method DatetimeArray.day_name of <panda...
# 2  <bound method DatetimeArray.day_name of <panda...
# 3  <bound method DatetimeArray.day_name of <panda...
