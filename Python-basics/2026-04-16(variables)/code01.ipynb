# %%
print("hello",end=" ")
print("good",end=" ")
print("bye",end=" ")

print("hello",end="&")
print("good",end="%")
print("bye",end="#")
# Out:
# hello good bye hello&good%bye#

# %%
x = 100
y = 200
z = 300
print(x,y,z,end="#")
# Out:
# 100 200 300#

# %%
print(10,2,2005,sep="/")
print(10,2,2008,sep="-")
# Out:
# 10/2/2005
# 10-2-2008
