# %%
class A():
    x = int(input("Enter the value of x:-"))
    y = int(input("Enter the value of y:-"))
    z = x+y
# print(x)   #error due to out of class
# print(y)
# print(z)    
print(A.x)
print(A.y)
print(A.z)
# Out:
# 2
# 3
# 5

# %%
class A():
    x = int(input("Enter the value of x:-"))
    y = int(input("Enter the value of y:-"))
    z = x+y
    print(x)
    print(y)
    print(z)
print(A.y)
print(A.x)
print(A.z)
# Out:
# 2
# 3
# 5
# 3
# 2
# 5

# %%
class A():
    x = int(input("Enter the value of x:-"))
    y = int(input("Enter the value of y:-"))
    z = x+y
    print(x)
    print(y)
    print(z)

print(A.y)    #address object
print(A.x)
print(A.z)    
print(A)

k = A()
print(k)
print(k.x)
print(k.y)          
print(k.z)

print(A().x)
print(A().y)        #accumate object
print(A().z)   

print(id(k))
print(id(A()))
# Out:
# 2
# 3
# 5
# 3
# 2
# 5
# <class '__main__.A'>
# ...
# 2
# 3
# 5
# 2
# 3
# 5
# 1540960390512
# 1540960259120

# %%
class A:
    pass
k1 = A()
k2= A()
print(id(k1))
print(id(k2))
# Out:
# 2146492123856
# 2146490099792

# %%
class A:
    k = input("enter the value k: ")
    l = input("enter the value l: ")
    m = k+l
    print(m)
    def detail(self):
        name = input("enter the name:")
        age = input("enter the age:")
        print(name)
        print(age)
        
        print(self.m)
r = A()
r.detail()
# Out:
# 2
# 3
# shivrsh
# 2

# %%
g = ['shivesh','anjali','sumant']
print(id(g))
print(id(g[0]))
print(id(g[1]))
print(id(g[2]))
print(type(g))
print(type(g[0]))
# Out:
# 2304190847040
# 2304184650752
# 2304184655648
# 2304184654976
# <class 'list'>
# <class 'str'>

# %%
class Class:
    gf = ["shivesh",'purnima','bewsti']
print(Class.gf)
print(id(Class.gf))
print(Class.gf[0])
print(Class.gf[1])
Class.gf[0] = 130012
Class.gf[2] = "anjali"
k = Class()
print(k.gf[2])
print(k.gf)
k.gf[0] = 'shivesh'
k.gf[2] = ['anjali','shreya']
print(k.gf)
# Out:
# ['shivesh', 'purnima', 'bewsti']
# 2304191528064
# shivesh
# purnima
# anjali
# [130012, 'purnima', 'anjali']
# ['shivesh', 'purnima', ['anjali', 'shreya']]

# %%
class ram:
    x = int(input("enter the 1st value:"))
    y = int(input("enter the 1st value:"))  
    print(x)
    print(y)
    def add(self):
        x = int(input("enter the 1st value:"))
        y = int(input("enter the 1st value:"))
        print(x)
        print(y)

g = ram()
print(g.x , g.y )
g.add()
g.x =400
g.y =600
print(g.x)
print(g.y)
# Out:
# 2
# 3
# 2 3
# 4
# 5
# 400
# 600
