# %%
x = 5
while x<=10:
    print("hello")
    x +=1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello

# %%
# while (True):
    print("hii")
# Out:
#   Cell In[4], line 2
#     print("hii")
#     ^
# IndentationError: unexpected indent

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y : "))    
if x<y:
    while x<=y:
        print("value: ",x)
        x = x+1
else:
    print("sorry user pls check the order")
    print("try again")
# Out:
# sorry user pls check the order
# try again

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y : "))  
sum = 0 
if x<y:
    while x<=y:
        print("value: ",x)
        sum = sum + x
        x = x+1
else:
    print("sorry user pls check the order")
    print("try again")     
print(sum)
# Out:
# value:  2
# value:  3
# 5

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y: "))
no_even  = 0
no_odd = 0
sum_even = 0
sum_odd = 0
while (x<=y): 
    if x%2==0:                                      # calculate total even and odd number and also sum of even and odd
        print("even numbrer: ",x)
        no_even =  no_even+1
        sum_even = sum_even+x
    else:
        print("odd number : ",x)
        no_odd = no_odd+1
        sum_odd = sum_odd+x
    x = x+1    
print("total number of even:", no_even)            
print("total number of odd:",no_odd)      
print(" totralsum of even : ",sum_even)                  
print("total sum of odd : ",sum_odd)
# Out:
# even numbrer:  2
# odd number :  3
# even numbrer:  4
# odd number :  5
# even numbrer:  6
# total number of even: 3
# total number of odd: 2
#  totralsum of even :  12
# total sum of odd :  8

# %%
x = int(input("emter the value: "))
temp = x 
fact = 1
while temp!=0:                           #calculate factotrial
    fact = temp*fact
    temp = temp-1
print(f"the factorial of{x} is= {fact}")
# Out:
# the factorial pf8 is= 40320

# %%
x = 2522
temp = x
while temp!=0:
    rem = temp%10      # resvere number print karega
    print(rem)
    temp = temp//10
# Out:
# 2
# 2
# 5
# 2

# %%
x = int(input("Enter the value: "))
temp = x
while temp!=0:
    print(temp)
    rem = temp%10                     
    print("digitis now",rem)
    temp = temp//10
    print(temp)
# Out:
# 8894734
# digitis now 4
# 889473
# 889473
# digitis now 3
# 88947
# 88947
# digitis now 7
# 8894
# 8894
# digitis now 4
# 889
# 889
# digitis now 9
# 88
# 88
# digitis now 8
# 8
# 8
# digitis now 8
# 0

# %%
num = int(input("Enter the value: "))
temp = num                                  
while temp!=0:
    rem = temp%10                 #number ko piche se reverse kare sath hee even and odd vii dedict karega
    if rem%2==0:
        print("even number",rem)
    else:
        print("odd number",rem) 
    temp = temp//10
# Out:
# even number 6
# odd number 5
# odd number 5
# odd number 3
# odd number 3
