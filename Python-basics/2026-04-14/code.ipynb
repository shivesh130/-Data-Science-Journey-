# %%
x = 100
y = 100
z = 100
k = 100
print(x,id(x))
print(x,id(y))
print(x,id(z))
print(x,id(k))
print(x==y)     #"==" equality operator check both value and hash code address is only applicable of linear object
print(x==x)
print(x==z)
print(x==k)
# print(x in x)     #"in" is same as equality but 'in' also work on non-linear objects
# print(x in y)
print(x is x)
print(x is y)   #"is" only comapre value
print(x is z)
# Out:
# 100 140703969292296
# 100 140703969292296
# 100 140703969292296
# 100 140703969292296
# True
# True
# True
# True
# True
# True
# True

# %%
x,y,z = 100,200,300
print(x)
print(y)
print(z)

a,b,c=100
print(a,b,c) #error
# Out:
# 100
# 200
# 300
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 print(y)
#       4 print(z)
# ----> 6 a,b,c=100
#       7 print(a,b,c) #error
#       9 x=y=z=100
#
# TypeError: cannot unpack non-iterable int object

# %%
x=y=z=100
print(x is y , x==y)
print(y is x , y==x)
print(z is x , z==x)
# Out:
# True True
# True True
# True True

# %%
x = 100
y = '100'
print(id(x)== id(int(y)))
print(x*y)
print(id(x) is id(y))
print(type(id(x)) == type(id(int(y))))
# Out:
# True
# 
# False
# True

# %%
x,y,z="abc"
print(x)
print(y)
print(z)
# Out:
# a
# b
# c

# %%
x,*y = 100,200,300,300,400
print(x)
print(y)
# Out:
# 100
# [200, 300, 300, 400]

# %%
*x,y =100,3304,898
print(x)
print(y)
# Out:
# [100, 3304]
# 898

# %%
*x,*y=10,300,500,5006
print(x)
print(y)
# Out:
#   Cell In[10], line 1
#     *x,*y=10,300,500,5006
#     ^
# SyntaxError: multiple starred expressions in assignment
