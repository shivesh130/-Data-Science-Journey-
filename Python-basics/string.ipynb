# %%
my_string = input("enter:")
count = 0
for i in my_string:
    count +=1
print(count)
# Out:
# 7

# %%
my_string = input("enter:")
string = ""
print(my_string)
for ch in my_string:
    string =ch + string
print(string)
# Out:
# shivesh
# hsevihs

# %%
# Out:
# 6
# Not palindrome
